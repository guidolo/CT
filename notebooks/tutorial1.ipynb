# %%
from core.trade_service.traders.MA_Trader import MA_Trader
from core.analitics.basic_plots import to_pandas
from datetime import datetime

# %%
model2 = MA_Trader(mode='sim',
                   symbol='BTCUSDT',
                  period_long=25, 
                  period_short=14,
                 panic= -0.04,
                 interval_group='1h', 
                 interval_source='1h',
                 start_time=datetime.fromisoformat('2020-01-01')
                 )

# %%
model2.evaluate()

# %%
data_trade = to_pandas(model2)

# %%
data_trade.loc[data_trade.gan < 0, 'gan'].sum()
# Out:
# -109.40053601948367

# %%
data_trade.loc[data_trade.gan > 0, 'gan'].sum()
# Out:
# 288.11882867386214

# %%
data_trade.set_index('start_datetime').gan.plot()
